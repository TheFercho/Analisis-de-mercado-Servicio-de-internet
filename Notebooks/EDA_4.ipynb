# %%
import pandas as pd
from matplotlib import pyplot as pyplot
import sweetviz as sv

# %%
df=pd.read_csv('./4_Ingresos_por_operación _Internet_fijo_OK.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 34 to 0
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Año                        35 non-null     object
#  1   Trimestre                  35 non-null     object
#  2   Ingresos (miles de pesos)  35 non-null     int32
#  3   Periodo                    35 non-null     object
# dtypes: int32(1), object(3)
# memory usage: 1.2+ KB

# %%
df_telefonia=pd.read_csv('./5_ingresos_trimestrales_telefonia_fija_OK.csv')

# %%
df_telefonia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Año                    35 non-null     object
#  1   Trimestre              35 non-null     object
#  2   Ingresos (miles de $)  35 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 972.0+ bytes

# %%
df_telefonia.head(3)
# Out:
#     Año Trimestre  Ingresos (miles de $) Año-Trimestre
# 0  2022         3                2916071       2022-T3
# 1  2022         2                2974865       2022-T2
# 2  2022         1                3105462       2022-T1

# %%
df[['Año','Trimestre']]=df[['Año','Trimestre']].astype(str)
df_telefonia[['Año','Trimestre']]=df[['Año','Trimestre']].astype(str)

# %%
df.head(3)
# Out:
#      Año Trimestre  Ingresos (miles de pesos)        Periodo Año-Trimestre
# 34  2014         1                    2984054   Ene-Mar 2014       2014-T1
# 33  2014         2                    3270816   Abr-Jun 2014       2014-T2
# 32  2014         3                    3478638  Jul-Sept 2014       2014-T3

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
columna_ingresos=df['Ingresos (miles de pesos)']
columna_ingresos_tel=df_telefonia['Ingresos (miles de $)']

# %%
df['Año-Trimestre']=df['Año']+'-T'+df['Trimestre']
df_telefonia['Año-Trimestre']=df_telefonia['Año']+'-T'+df_telefonia['Trimestre']

# %%
plt.figure(figsize=(12,6))

#for anio in df['Año']:
    #df_pesos = df[['Ingresos (miles de pesos)']]
x = df['Año'].astype(str) + '-' + df['Trimestre'].astype(str)
y1,y2 = df['Ingresos (miles de pesos)'],df_telefonia['Ingresos (miles de $)']
plt.ylabel('(miles de millones pesos)')
plt.xticks(rotation=90)
#plt.plot(x,y1,y2,linewidth=5,label='')

# Plotea la primera línea con su etiqueta
plt.plot(x, y1, linewidth=5, label='Ingresos Trimestrales de Internet')

# Plotea la segunda línea con su etiqueta
plt.plot(x, y2, linewidth=5, label='Ingresos Trimestrales de Telefonía Fija')

#Establece la escala del eje 'y'

# Calcula los límites mínimo y máximo de la columna 'Ingresos (miles de pesos)'
#y_min = df['Ingresos (miles de pesos)'].min()
#y_max = df['Ingresos (miles de pesos)'].max()
#plt.ylim(y_min,y_max)

plt.legend(loc='upper left')  # Agregar leyenda
plt.tight_layout()  # Ajustar el espaciado
plt.show()

# %% [markdown]
# Nota : Acá podemos observar cómo a partir de 2017, los ingresos(en miles de millones de pesos) por servicios de internet superan y continúan en ascenso ante la caída de la recaudación en telefonía fija.
#
# Recordemos que con la llegada de la telefonía celular(Smart phones) y los cambios de hábitos y costumbres de las nuevas generaciones, es lógica y predecible la tendencia que se observa en la gráfica.
